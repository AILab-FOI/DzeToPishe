# %% [markdown]
# <div align="center" style="font-size: 2.5em; font-weight: bold; margin-bottom: 10px;">Diplomski rad — GraphRAG pristup</div>
#
# <div align="center" style="font-size: 1.2em; color: #555;">Neo4j · Qwen2.5-14B-Instruct · multilingual-e5-large · BERTić NER</div>
#
# <div align="right" style="font-style: italic; color: #666;">by Zlatko Pračić</div>

# %% [markdown]
# ## 1. Postavljanje okruženja
#
# Instalacija svih potrebnih biblioteka, montiranje Google Drivea, uvoz modula i autentifikacija.

# %% [markdown]
# ### Instalacija potrebnih biblioteka

# %%
# !pip install -q -U bitsandbytes transformers accelerate sentencepiece
# !pip install -q -U sentence-transformers
# !pip install -q python-docx pdfplumber==0.11.0
# !pip install -q neo4j tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 140.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 149.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 134.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 26.3 MB/s eta 0:00:00

# %% [markdown]
# ---
#
# **bitsandbytes**
# https://huggingface.co/docs/transformers/en/quantization/bitsandbytes
#
# **transformers / pipeline**
# https://huggingface.co/docs/transformers/pipeline_tutorial
#
# **sentence-transformers**
# https://www.sbert.net/
#
# **neo4j**
# https://neo4j.com/docs/python-manual/current/
# https://pypi.org/project/neo4j/
#
# **tqdm**
# https://tqdm.github.io/
#
# **python-docx**
# https://python-docx.readthedocs.io/
#
# **pdfplumber**
# https://github.com/jsvine/pdfplumber

# %% [markdown]
# ### Montiranje Google Drivea

# %% [markdown]
# ### Uvoz biblioteka

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, BitsAndBytesConfig, GenerationConfig
from google.colab import userdata
from huggingface_hub import login
from sentence_transformers import SentenceTransformer
from neo4j import GraphDatabase
from tqdm import tqdm
from docx import Document as DocxDocument
import pdfplumber
from pathlib import Path
from copy import deepcopy
import torch
import time
import json
import os
import re
import logging
import pandas as pd

# %% [markdown]
# ### Autentifikacija s Hugging Face

# %%
token = userdata.get('HF_TOKEN')
login(token)

# %% [markdown]
# **Učitavanje modela**

# %%
# ============================================================
# OPCIJA A: čitanje LLM-a izravno s Google Drivea
# Pokreni OVU ćeliju ILI ćeliju B — ne obje.
# ============================================================

# model_name = "Qwen/Qwen2.5-14B-Instruct"
model_name = "utter-project/EuroLLM-22B-Instruct-2512"

from google.colab import drive
drive.mount('/content/drive')

os.environ["HF_HOME"] = "/content/drive/MyDrive/hf_cache"
os.environ["HF_HUB_OFFLINE"] = "1"
os.environ["TRANSFORMERS_OFFLINE"] = "1"

print(f"Model: {model_name}")
print(f"Čitanje s Drivea: {os.environ['HF_HOME']}")
# Out:
# Mounted at /content/drive
# Model: utter-project/EuroLLM-22B-Instruct-2512
# Čitanje s Drivea: /content/drive/MyDrive/hf_cache

# %%
# ============================================================
# OPCIJA B: kopiranje LLM-a na /content (brži disk) pa čitanje
# Pokreni OVU ćeliju ILI ćeliju A — ne obje.
# ============================================================

# model_name = "Qwen/Qwen2.5-14B-Instruct"
model_name = "utter-project/EuroLLM-22B-Instruct-2512"

from google.colab import drive
drive.mount('/content/drive')

hf_ime    = "models--" + model_name.replace("/", "--")
izvor     = f"/content/drive/MyDrive/hf_cache/hub/{hf_ime}"
odrediste = f"/content/hf_cache/hub/{hf_ime}"

if not os.path.exists(odrediste):
    print("Kopiranje modela na /content...")
    # !mkdir -p /content/hf_cache/hub
    # !cp -r {izvor} {odrediste}
    print("Gotovo.")

os.environ["HF_HOME"] = "/content/hf_cache"
os.environ["HF_HUB_OFFLINE"] = "1"
os.environ["TRANSFORMERS_OFFLINE"] = "1"

print(f"Model: {model_name}")
print(f"Čitanje s /content: {os.environ['HF_HOME']}")

# %%
token = userdata.get('HF_TOKEN')
login(token)

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4"
)

pipe = pipeline(
    "text-generation",
    model=model_name,
    dtype=torch.float16,
    device_map="auto",
    model_kwargs={"quantization_config": quantization_config}
)

pipe.model.generation_config.max_length = 8192
# Out:
# config.json:   0%|          | 0.00/680 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/40.3k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/489 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/47.3k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/2.41M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.8M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/443 [00:00<?, ?B/s]

# %% [markdown]
# ### Konfiguracija kvantizacije i učitavanje LLM modela

# %% [markdown]
# ### Odabir LLM modela
#
# [Qwen2.5 model](https://huggingface.co/Qwen/Qwen2.5-14B-Instruct)

# %% [markdown]
# ### Kreiranje pipeline-a za generaciju teksta
#
# [Pipeline](https://huggingface.co/docs/transformers/pipeline_tutorial)

# %% [markdown]
# ## 3. Konfiguracija Neo4j baze podataka
#
# Definiramo parametre veze s Neo4j bazom i konfiguriramo retrieval.

# %%
NEO4J_URI      = 'neo4j+s://ad1afaa8.databases.neo4j.io'
NEO4J_USER     = 'ad1afaa8'
NEO4J_PASSWORD = userdata.get('Neo4j')

# --- Retrieval konfiguracija -------------------------------------
# Finalni broj clanaka u kontekstu, po kategoriji pitanja.
# Kompleksna pitanja trebaju siri kontekst (sinteza kroz vise akata).
GRAPH_TOP_K = {
    'jednostavno':                5,
    'kompleksno_jedan_dokument':  8,
    'kompleksno_vise_dokumenata': 12,
}
GRAPH_TOP_K_DEFAULT = 5

# Broj kandidata iz vektorskih indeksa PRIJE prosirenja grafom
GRAPH_VECTOR_POOL = 30

# Najvise seed-clanaka po pojedinom zakonu — garantira pokrivenost
# svih dokumenata kod medudokumentnih pitanja
GRAPH_PER_DOC_CAP = 3

# Maksimalna duljina teksta jednog clanka u kontekstu (rezanje pri
# SASTAVLJANJU konteksta, ne pri spremanju u bazu)
GRAPH_MAX_CHARS_PO_CLANKU = 4000

# Tezine po tipu veze: mnozitelj score-a seeda za susjeda dohvacenog
# tom vezom. Ekspertne veze imaju prednost nad automatskima.
GRAPH_REL_WEIGHTS = {
    'RAZRADJUJE':  1.00,   # ekspertna medudokumentna veza — bez penaltija
    'ISTA_TEMA':   0.95,   # ekspertna tematska veza
    'UPUCUJE_NA':  0.85,   # automatska eksplicitna referenca
    'SPOMINJE':    0.70,   # zajednicki entitet (najslabiji signal)
}

print('\u2713 Neo4j i retrieval konfiguracija ucitana')
# Out:
# ✓ Neo4j i retrieval konfiguracija ucitana

# %% [markdown]
# ### Konekcija s Neo4j i kreiranje sheme grafa
#
# Uspostavljamo vezu s Neo4j bazom i kreiramo:
# - **Unique constraints** za čvorove Zakon i Clanak
# - **Vektorski indeks** za semantičko pretraživanje embeddings
#
# [Neo4j Python Driver](https://neo4j.com/docs/python-manual/current/)

# %%
neo4j_driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

def neo4j_run(query, params=None):
    with neo4j_driver.session() as session:
        return list(session.run(query, params or {}))

_transformers_logger = logging.getLogger("transformers.modeling_utils")
_prev_level = _transformers_logger.level
_transformers_logger.setLevel(logging.ERROR)

embed_model = SentenceTransformer("intfloat/multilingual-e5-large")

_transformers_logger.setLevel(_prev_level)

EMBEDDING_DIM = embed_model.get_embedding_dimension()  # 1024 za e5-large

SCHEMA_QUERIES = [
    'CREATE CONSTRAINT IF NOT EXISTS FOR (z:Zakon) REQUIRE z.id IS UNIQUE',
    'CREATE CONSTRAINT IF NOT EXISTS FOR (c:Clanak) REQUIRE c.id IS UNIQUE',
    'CREATE CONSTRAINT IF NOT EXISTS FOR (e:Entitet) REQUIRE e.naziv IS UNIQUE',
    f'''CREATE VECTOR INDEX clanak_embedding IF NOT EXISTS
    FOR (c:Clanak) ON (c.embedding)
    OPTIONS {{
        indexConfig: {{
            `vector.dimensions`: {EMBEDDING_DIM},
            `vector.similarity_function`: 'cosine'
        }}
    }}''',
]

for q in SCHEMA_QUERIES:
    try:
        neo4j_run(q)
    except Exception as e:
        print(f'  (info) {e}')

neo4j_driver.verify_connectivity()
print(f'✓ Neo4j konekcija OK | Embedding dimenzija: {EMBEDDING_DIM}')
# Out:
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/160k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# [transformers] The following layers were not sharded: encoder.layer.*.attention.self.query.weight, embeddings.LayerNorm.weight, encoder.layer.*.intermediate.dense.weight, pooler.dense.weight, encoder.layer.*.attention.self.key.weight, embeddings.token_type_embeddings.weight, encoder.layer.*.output.dense.bias, encoder.layer.*.attention.output.dense.weight, pooler.dense.bias, encoder.layer.*.attention.output.dense.bias, encoder.layer.*.output.LayerNorm.weight, embeddings.LayerNorm.bias, encoder.layer.*.attention.self.query.bias, encoder.layer.*.attention.self.value.weight, encoder.layer.*.attention.self.value.bias, encoder.layer.*.intermediate.dense.bias, encoder.layer.*.attention.self.key.bias, encoder.layer.*.output.dense.weight, encoder.layer.*.output.LayerNorm.bias, encoder.layer.*.attention.output.LayerNorm.bias, embeddings.word_embeddings.weight, encoder.layer.*.attention.output.LayerNorm.weight, embeddings.position_embeddings.weight
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/201 [00:00<?, ?B/s]
# ✓ Neo4j konekcija OK | Embedding dimenzija: 1024

# %% [markdown]
# ## 4. Sistemska poruka i funkcija generacije
#
# Definiramo sistemsku poruku i funkciju za generaciju odgovora LLM modelom.

# %%
SYSTEM_PROMPT = (
"Ti si pravni stručnjak specijaliziran za zakonodavstvo Republike Hrvatske, posebno za Zakon o obrani, Zakon o službi u Oružanim snagama RH i pripadajuće pravilnike."
"\n\nPravila odgovaranja:"
"\n1. Jezik odgovora: hrvatski, latinica."
"\n2. Navedi konkretne članke zakona, brojčane vrijednosti i nadležna tijela."
"\n3. Ako je dostupan kontekst, koristi SAMO informacije iz njega."
"\n4. Ako kontekst ne sadržava odgovor, odgovori na temelju općeg znanja i dodaj: 'Napomena: ova informacija nije pronađena u dostupnim dokumentima."
"\n5. Odgovor neka bude koncizan i strukturiran — bez nepotrebnih uvoda."
)

# %%
csv_path = '/content/drive/My Drive/diplomskiRad/rezultati.csv'

# %%
def generate_response(messages, max_new_tokens=512, temperature=0.5, do_sample=True):
    final_messages = list(messages)

    model_max_length = getattr(pipe.tokenizer, 'model_max_length', 8192)
    if model_max_length > 100000:
        model_max_length = 8192

    input_text = pipe.tokenizer.apply_chat_template(final_messages, tokenize=False)
    input_token_count = len(pipe.tokenizer.encode(input_text))
    max_allowed_input = model_max_length - max_new_tokens

    if input_token_count > max_allowed_input:
        print(f"Upozorenje: input ({input_token_count} tokena) prelazi limit ({max_allowed_input}). Skraćujem kontekst.")
        if final_messages and final_messages[0]["role"] == "system":
            system_content = final_messages[0]["content"]
            while input_token_count > max_allowed_input and "\n\n---\n\n" in system_content:
                last_chunk_start = system_content.rfind("\n\n---\n\n")
                system_content = system_content[:last_chunk_start]
                final_messages[0]["content"] = system_content
                input_text = pipe.tokenizer.apply_chat_template(final_messages, tokenize=False)
                input_token_count = len(pipe.tokenizer.encode(input_text))
            print(f"  Skraćeno na {input_token_count} tokena.")

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    gen_config = deepcopy(pipe.model.generation_config)
    gen_config.max_new_tokens = max_new_tokens
    gen_config.temperature = temperature
    gen_config.do_sample = do_sample
    gen_config.repetition_penalty = 1.1

    vrijeme_upita = time.time()

    response = pipe(final_messages, generation_config=gen_config)

    answer = ""
    for message in response[0]['generated_text']:
        if message['role'] == 'assistant':
            answer = message['content']
            break

    stripped_answer = answer.strip()
    if not re.search(r'[.!?]$', stripped_answer) and len(stripped_answer.split()) > 5:
        last_punctuation_index = -1
        for i in range(len(stripped_answer) - 1, -1, -1):
            if stripped_answer[i] in ['.', '?', '!']:
                last_punctuation_index = i
                break
        if last_punctuation_index != -1:
            answer = stripped_answer[:last_punctuation_index + 1]
        else:
            words = stripped_answer.split()
            answer = ' '.join(words[:-1]) + '...' if len(words) > 1 else (words[0] if words else '')
    else:
        answer = stripped_answer

    vrijeme_odgovora = time.time()
    ukupno_vrijeme = vrijeme_odgovora - vrijeme_upita

    print("Generirani odgovor:")
    print(answer)
    print(f"Ukupno vrijeme za odgovor: {ukupno_vrijeme:.2f} sekundi")

    return answer, ukupno_vrijeme

# %% [markdown]
# ## 5. NER model za ekstrakciju entiteta
#
# Za prepoznavanje imenskih entiteta (osobe, organizacije, mjesta) iz pravnih tekstova koristimo višejezični BERTić model.
#
# [BERTić NER model](https://huggingface.co/classla/bcms-bertic-ner)

# %%
graph_ner_pipe = pipeline(
    'ner',
    model='classla/bcms-bertic-ner',
    aggregation_strategy='simple',
    device=0,
)

def graph_extract_entities(text: str) -> list:
    # ============================================================
    # IZMJENA GRAPH-1: NER preko cijelog clanka klizNIM prozorom.
    # Prije: graph_ner_pipe(text[:512]) -> sve nakon 512. znaka se
    # bacalo, pa su entiteti iz ostatka clanka nedostajali i nastajalo
    # je manje (i nepotpunih) SPOMINJE veza. Sada prozor 512 s
    # preklapanjem 128 pokriva cijeli tekst clanka.
    # ============================================================
    if not text or len(text.strip()) < 10:
        return []
    try:
        entities, seen = [], set()
        for start in range(0, len(text), 384):          # korak 384 = prozor 512 - preklapanje 128
            prozor = text[start:start + 512]
            if len(prozor.strip()) < 10:
                continue
            for r in graph_ner_pipe(prozor):
                naziv = r['word'].strip()
                if naziv and naziv not in seen and len(naziv) > 2:
                    entities.append({'naziv': naziv, 'tip': r['entity_group']})
                    seen.add(naziv)
        return entities
    except Exception:
        return []

print('✓ NER model ucitan')
# Out:
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/231k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ✓ NER model ucitan

# %% [markdown]
# ## 6. Parser pravnih dokumenata
#
# Parser čita .docx datoteke i izvlači strukturu zakona po člancima, stavcima, upućivanjima i obvezama.

# %%
# Detekcija clanka po SADRZAJU teksta (ne po stilu/bold-u).
# Hrvatski zakoni s NN koriste custom stilove ('clanak', 'clanak-'),
# tekst nije bold, a naslov moze imati sufiks npr. "Clanak 3. (NN 73/13)".
#
# ISPRAVKA: dodan fallback — tekst koji ne odgovara obrascu clanka
# (preambula, tekst prije prvog clanka, dokument bez prepoznatih
# clanaka) vise se ne odbacuje, nego ulazi u graf kao pseudo-clanci.
# Time GraphRAG korpus postaje ekvivalentan RAG korpusu (koji ima
# chunk_text_with_overlap fallback) i nema tihog gubitka sadrzaja.

CLANAK_RE      = re.compile(r'^[\u010c\u010dCc]lanak\s+(\d+[a-z]?)\.?(?:\s|$)', re.IGNORECASE)
STAVAK_PATTERN = re.compile(r'^\((\d+)\)\s+')
# ============================================================
# IZMJENA GRAPH-2: UPUTA_PATTERN sada hvata I ciljni akt reference,
# ne samo broj clanka. Prije se snimao samo broj (npr. "70") pa se
# veza UVIJEK gradila unutar ISTOG dokumenta -> nijedna UPUCUJE_NA
# veza nije mogla biti medudokumentna. Sada razlikujemo je li
# referenca na vlastiti akt ("ovog Zakona") ili na drugi imenom.
# ============================================================
UPUTA_PATTERN  = re.compile(
    r'[\u010c\u010dCc]lank[ua]?\s+(\d+[a-z]?)\.?\s+'
    r'(ovog[a]?\s+(?:Pravilnika|Zakona)'
    r'|Ustav[a]?'
    r'|Zakona\s+o\s+obrani'
    r'|Zakona\s+o\s+slu\u017ebi[a-z\u0107\u010d\u0111\u0161\u017e\s]*?snagama'
    r'|Pravilnika\s+o\s+[a-z\u0107\u010d\u0111\u0161\u017e\s]+?)',
    re.IGNORECASE
)

def _ciljni_akt(fraza):
    # Vraca kratki kod ciljnog akta ili None (ako je referenca na
    # vlastiti dokument -> "ovog Zakona/Pravilnika").
    f = fraza.lower()
    if 'ovog' in f:                     return None          # samoreferenca
    if 'ustav' in f:                    return 'ustav'
    if 'slu\u017ebi' in f or 'sluzbi' in f: return 'sluzba_osrh'
    if 'obrani' in f:                   return 'obrana'
    if 'pravilnik' in f:                return 'pravilnik'
    return None

FALLBACK_CHUNK_LEN = 1200  # kao RAG chunker

def _klasificiraj_obvezu(tekst: str):
    t = tekst.lower()
    if any(k in t for k in ['du\u017ean', 'duzan', 'obvezan', 'obvezna', 'mora', 'obvezuje se']):
        return 'OBVEZA'
    if any(k in t for k in ['zabranjeno', 'nije dopu\u0161teno', 'nije dopusteno', 'ne smije']):
        return 'ZABRANA'
    if any(k in t for k in ['ima pravo', 'ovla\u0161ten', 'ovlasten', 'mo\u017ee', 'moze']):
        return 'PRAVO'
    return None

def _fallback_pseudo_clanci(tekst: str, prefix: str):
    """Tekst izvan obrasca clanka rezemo u pseudo-clanke (fallback,
    identican duh RAG chunkera) da nista ne ispadne iz grafa."""
    tekst = ' '.join(tekst.split())
    if len(tekst) < 200:          # trivijalni ostaci (datumi, potpisi)
        return []
    out, i, n = [], 0, 1
    while i < len(tekst):
        chunk = tekst[i:i + FALLBACK_CHUNK_LEN]
        out.append({'broj': f'{prefix}{n}', 'tekst': chunk,
                    'stavci': [], 'upucivanja': [], 'obveze': []})
        i += FALLBACK_CHUNK_LEN
        n += 1
    return out

def _parse_paragraphs(paragraphs, naziv):
    """Zajednicka logika za docx i pdf: paragrafe pretvara u clanke,
    uz fallback za tekst prije prvog clanka i dokumente bez clanaka."""
    clanaci, current = [], None
    pre_text = []                      # tekst PRIJE prvog clanka

    for tekst in paragraphs:
        tekst = tekst.strip()
        if not tekst:
            continue

        m = CLANAK_RE.match(tekst)
        if m:
            if current:
                clanaci.append(current)
            current = {'broj': m.group(1), 'tekst': '', 'stavci': [],
                       'upucivanja': [], 'obveze': []}
            continue

        if current is None:
            pre_text.append(tekst)     # FALLBACK: ne odbacuj
            continue

        if STAVAK_PATTERN.match(tekst):
            current['stavci'].append(tekst)
        else:
            current['tekst'] += ' ' + tekst

        for um in UPUTA_PATTERN.finditer(tekst):
            br  = um.group(1)
            akt = _ciljni_akt(um.group(2))      # IZMJENA GRAPH-2: ciljni akt
            ref = (br, akt)                      # par (broj_clanka, ciljni_akt|None)
            if br and ref not in current['upucivanja']:
                current['upucivanja'].append(ref)

        tip = _klasificiraj_obvezu(tekst)
        if tip:
            current['obveze'].append({'tip': tip, 'tekst': tekst[:300]})

    if current:
        clanaci.append(current)

    # FALLBACK 1: preambula / tekst prije prvog clanka
    pseudo = _fallback_pseudo_clanci(' '.join(pre_text), 'pre')
    # FALLBACK 2: dokument bez ijednog prepoznatog clanka
    if not clanaci and not pseudo:
        cijeli = ' '.join(paragraphs)
        pseudo = _fallback_pseudo_clanci(cijeli, 'chunk')

    clanaci = pseudo + clanaci
    print(f'  Parsiran: {naziv} \u2014 {len(clanaci)} clanaka'
          f' (od toga {len(pseudo)} fallback)')
    return {'naziv': naziv, 'clanaci': clanaci}

def graph_parse_docx(filepath: str) -> dict:
    doc = DocxDocument(filepath)
    naziv = Path(filepath).stem.replace('_', ' ')
    for para in doc.paragraphs[:15]:
        sn = para.style.name.lower()
        if ('heading' in sn or 'naslov' in sn or 'title' in sn) and len(para.text.strip()) > 10:
            naziv = para.text.strip()
            break
    return _parse_paragraphs([p.text for p in doc.paragraphs], naziv)

def graph_parse_pdf(filepath: str) -> dict:
    import pdfplumber
    naziv = Path(filepath).stem.replace('_', ' ')
    lines = []
    try:
        with pdfplumber.open(filepath) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    lines.extend(page_text.split("\n"))
    except Exception as e:
        print(f'  Greska pri citanju PDF-a {filepath}: {e}')
        return {'naziv': naziv, 'clanaci': []}

    # Grupiranje linija u paragrafe (clanak / stavak / obicni tekst)
    paragraphs, current_para = [], []
    for line in lines:
        line = line.strip()
        if not line:
            if current_para:
                paragraphs.append(" ".join(current_para))
                current_para = []
            continue
        if CLANAK_RE.match(line):
            if current_para:
                paragraphs.append(" ".join(current_para))
                current_para = []
            paragraphs.append(line)
        elif STAVAK_PATTERN.match(line):
            if current_para:
                paragraphs.append(" ".join(current_para))
            current_para = [line]
        else:
            current_para.append(line) if current_para else current_para.append(line)
    if current_para:
        paragraphs.append(" ".join(current_para))

    return _parse_paragraphs(paragraphs, naziv)

print('\u2713 GraphRAG docx/pdf parser ucitan (s fallbackom)')
# Out:
# ✓ GraphRAG docx/pdf parser ucitan (s fallbackom)

# %% [markdown]
# ## 7. Ingestija zakona u Neo4j
#
# Za svaki članak zakona:
# 1. Kreiramo čvor `(:Clanak)` s tekstom, brojem i vektorskim embeddingom
# 2. Kreiramo čvorove `(:Stavak)` s relacijom `[:IMA_STAVAK]`
# 3. Dodajemo relacije `[:UPUCUJE_NA]` između članaka koji se međusobno referiraju
# 4. Ekstrahiramo entitete (NER) i dodajemo `(:Entitet)` čvorove
# 5. Kreiramo `(:Obveza)` čvorove za klasificirane obveze

# %%
# ============================================================
# IZMJENA GRAPH-2 (pomocna): rjesavanje ciljnog akta -> zakon_id.
# Umjesto hardkodiranih ID-eva (koji ovise o imenima datoteka),
# citamo stvarne Zakon cvorove iz baze i mapiramo po nazivu.
# Poziva se lijeno (prvi put kad zatreba) i kesira rezultat.
# ============================================================
_AKT_ID_CACHE = {}

def _rijesi_zakon_id(akt, vlastiti_zakon_id):
    if akt is None:
        return vlastiti_zakon_id            # samoreferenca -> isti dokument
    if not _AKT_ID_CACHE:
        # napuni kes iz baze: naziv zakona (lower) -> id
        try:
            for row in neo4j_run('MATCH (z:Zakon) RETURN z.id AS id, z.naziv AS naziv'):
                naziv = (row['naziv'] or '').lower()
                zid   = row['id']
                if 'ustav' in naziv:
                    _AKT_ID_CACHE['ustav'] = zid
                elif 'slu\u017ebi' in naziv or 'sluzbi' in naziv:
                    _AKT_ID_CACHE['sluzba_osrh'] = zid
                elif 'obrani' in naziv:
                    _AKT_ID_CACHE['obrana'] = zid
        except Exception as e:
            print(f'  (info) _rijesi_zakon_id kes: {e}')
    # ako ciljni akt nije u bazi (npr. generic "pravilnik"), fallback
    # na vlastiti dokument -> ponasanje kao prije izmjene
    return _AKT_ID_CACHE.get(akt, vlastiti_zakon_id)

def graph_ensure_schema():
    """Idempotentno osigurava constraintove i vektorske indekse."""
    dim = embed_model.get_embedding_dimension()
    queries = [
        'CREATE CONSTRAINT IF NOT EXISTS FOR (z:Zakon) REQUIRE z.id IS UNIQUE',
        'CREATE CONSTRAINT IF NOT EXISTS FOR (c:Clanak) REQUIRE c.id IS UNIQUE',
        'CREATE CONSTRAINT IF NOT EXISTS FOR (s:Stavak) REQUIRE s.id IS UNIQUE',
        'CREATE CONSTRAINT IF NOT EXISTS FOR (e:Entitet) REQUIRE e.naziv IS UNIQUE',
        f'''CREATE VECTOR INDEX clanak_embedding IF NOT EXISTS
        FOR (c:Clanak) ON (c.embedding)
        OPTIONS {{
            indexConfig: {{
                `vector.dimensions`: {dim},
                `vector.similarity_function`: 'cosine'
            }}
        }}''',
        f'''CREATE VECTOR INDEX stavak_embedding IF NOT EXISTS
        FOR (s:Stavak) ON (s.embedding)
        OPTIONS {{
            indexConfig: {{
                `vector.dimensions`: {dim},
                `vector.similarity_function`: 'cosine'
            }}
        }}''',
    ]
    for q in queries:
        try:
            neo4j_run(q)
        except Exception as e:
            print(f'  (info) {e}')
    print(f'\u2713 Shema osigurana (indeksi clanak_embedding i stavak_embedding, dim={dim})')

def graph_embed(text: str) -> list:
    # Pun tekst — e5-large sam reze na 512 tokena pri enkodiranju
    vec = embed_model.encode(['passage: ' + text], normalize_embeddings=True)
    return vec[0].tolist()

def graph_ingest_zakon(zakon_data: dict, zakon_id: str):
    graph_ensure_schema()
    naziv = zakon_data['naziv']
    neo4j_run('MERGE (z:Zakon {id: $id}) SET z.naziv = $naziv',
              {'id': zakon_id, 'naziv': naziv})

    for cl in tqdm(zakon_data['clanaci'], desc=f'  Ingestija: {naziv[:30]}'):
        clanak_id = f'{zakon_id}_cl_{cl["broj"]}'
        full_text = (cl['tekst'].strip() + ' ' + ' '.join(cl['stavci'])).strip()
        if not full_text:
            continue

        embedding = graph_embed(full_text)

        # ISPRAVKA: pun tekst clanka, bez [:2000] truncationa.
        # Rezanje se (po potrebi) radi pri sastavljanju konteksta.
        neo4j_run('''
            MERGE (c:Clanak {id: $id})
            SET c.broj = $broj, c.tekst = $tekst,
                c.zakon_id = $zakon_id, c.embedding = $emb
            WITH c
            MATCH (z:Zakon {id: $zakon_id})
            MERGE (z)-[:SADRZI]->(c)
        ''', {'id': clanak_id, 'broj': cl['broj'], 'tekst': full_text,
              'zakon_id': zakon_id, 'emb': embedding})

        # ISPRAVKA: stavci dobivaju vlastite embeddinge — uska pitanja
        # pogadaju uski stavak, a dohvat vraca roditeljski clanak.
        for i, stavak in enumerate(cl['stavci']):
            neo4j_run('''
                MERGE (s:Stavak {id: $id})
                SET s.tekst = $tekst, s.redoslijed = $r, s.embedding = $emb
                WITH s MATCH (c:Clanak {id: $cid})
                MERGE (c)-[:IMA_STAVAK]->(s)
            ''', {'id': f'{clanak_id}_s{i}', 'tekst': stavak, 'r': i,
                  'cid': clanak_id, 'emb': graph_embed(stavak)})

        # ============================================================
        # IZMJENA GRAPH-2: UPUCUJE_NA sada moze biti MEDUDOKUMENTNA.
        # Ciljni akt (kod iz parsera) preslikavamo u stvarni zakon_id.
        # AKT_ID se gradi automatski iz vec ingestiranih Zakon cvorova
        # (naziv -> id), pa radi bez obzira na tocna imena datoteka.
        # Ako akt nije prepoznat (None ili 'pravilnik' bez tocnog
        # cilja), veza ostaje unutar vlastitog dokumenta (kao prije).
        # ============================================================
        for target_br, akt in cl['upucivanja']:
            ciljni_zakon = _rijesi_zakon_id(akt, zakon_id)   # IZMJENA GRAPH-2
            neo4j_run('''
                MERGE (t:Clanak {id: $tid})
                ON CREATE SET t.broj = $tbr, t.zakon_id = $zid
                WITH t MATCH (src:Clanak {id: $sid})
                MERGE (src)-[:UPUCUJE_NA]->(t)
            ''', {'tid': f'{ciljni_zakon}_cl_{target_br}', 'tbr': target_br,
                  'zid': ciljni_zakon, 'sid': clanak_id})

        for ent in graph_extract_entities(full_text):
            neo4j_run('''
                MERGE (e:Entitet {naziv: $naziv}) SET e.tip = $tip
                WITH e MATCH (c:Clanak {id: $cid})
                MERGE (c)-[:SPOMINJE]->(e)
            ''', {'naziv': ent['naziv'], 'tip': ent['tip'], 'cid': clanak_id})

        for ob in cl['obveze']:
            neo4j_run('''
                CREATE (o:Obveza {tekst: $tekst, tip: $tip})
                WITH o MATCH (c:Clanak {id: $cid})
                MERGE (c)-[:SADRZI_OBVEZU]->(o)
            ''', {'tekst': ob['tekst'], 'tip': ob['tip'], 'cid': clanak_id})

    print(f'\u2713 Zakon "{naziv}" upisan u Neo4j')

print('\u2713 Ingestija funkcije ucitane')
# Out:
# ✓ Ingestija funkcije ucitane

# %% [markdown]
# ### Učitavanje zakona iz Google Drivea u Neo4j
#
# Koristimo .docx dokumente iz Google Drivea, parsiramo ih i upisujemo u Neo4j.

# %%
# Brisanje svih čvorova i veza prije ponovne ingestije
neo4j_run('MATCH (n) DETACH DELETE n')
print('✓ Baza očišćena — svi čvorovi i veze obrisani.')
# Out:
# ✓ Baza očišćena — svi čvorovi i veze obrisani.

# %%
graph_docs_dir = '/content/drive/My Drive/diplomskiRad/Dokumenti'

if os.path.exists(graph_docs_dir):
    print(f'Ingestiram dokumente iz: {graph_docs_dir}\n')
    for file in os.listdir(graph_docs_dir):
        if file.endswith('.docx'):
            file_path = os.path.join(graph_docs_dir, file)
            zakon_id = Path(file).stem.lower().replace(' ', '_')[:50]
            zakon_data = graph_parse_docx(file_path)
            graph_ingest_zakon(zakon_data, zakon_id)
        elif file.endswith('.pdf'):
            file_path = os.path.join(graph_docs_dir, file)
            zakon_id = Path(file).stem.lower().replace(' ', '_')[:50]
            zakon_data = graph_parse_pdf(file_path)
            graph_ingest_zakon(zakon_data, zakon_id)
    print('\n✓ Svi zakoni upisani u Neo4j')
else:
    print(f'Mapa nije pronađena: {graph_docs_dir}')
# Out:
# Ingestiram dokumente iz: /content/drive/My Drive/diplomskiRad/Dokumenti
#
#   Parsiran: Pravilnik o temeljnom vojnom osposobljavanju — 23 clanaka (od toga 1 fallback)
# ✓ Shema osigurana (indeksi clanak_embedding i stavak_embedding, dim=1024)
#   Ingestija: Pravilnik o temeljnom vojnom o:  22%|██▏       | 5/23 [00:05<00:21,  1.20s/it][transformers] You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   Ingestija: Pravilnik o temeljnom vojnom o: 100%|██████████| 23/23 [00:25<00:00,  1.13s/it]
# ✓ Zakon "Pravilnik o temeljnom vojnom osposobljavanju" upisan u Neo4j
#   Parsiran: Ustav Republike Hrvatske 2018 — 154 clanaka (od toga 5 fallback)
# ✓ Shema osigurana (indeksi clanak_embedding i stavak_embedding, dim=1024)
#   Ingestija: Ustav Republike Hrvatske 2018: 100%|██████████| 154/154 [02:29<00:00,  1.03it/s]
# ✓ Zakon "Ustav Republike Hrvatske 2018" upisan u Neo4j
#   Parsiran: Zakon o obrani 2025 — 143 clanaka (od toga 2 fallback)
# ✓ Shema osigurana (indeksi clanak_embedding i stavak_embedding, dim=1024)
#   Ingestija: Zakon o obrani 2025: 100%|██████████| 143/143 [05:04<00:00,  2.13s/it]
# ✓ Zakon "Zakon o obrani 2025" upisan u Neo4j
#   Parsiran: Zakon o sluzbi u Oruzanim snagama Republike Hrvatske 2025 — 280 clanaka (od toga 2 fallback)
# ✓ Shema osigurana (indeksi clanak_embedding i stavak_embedding, dim=1024)
#   Ingestija: Zakon o sluzbi u Oruzanim snag: 100%|██████████| 280/280 [06:36<00:00,  1.41s/it]
# ✓ Zakon "Zakon o sluzbi u Oruzanim snagama Republike Hrvatske 2025" upisan u Neo4j
#
# ✓ Svi zakoni upisani u Neo4j

# %% [markdown]
# ## 8. Statistike grafa
#
# Prikazujemo ukupan broj čvorova i relacija u Neo4j grafu.

# %%
stats = neo4j_run('''
    MATCH (z:Zakon) WITH count(z) AS zakoni
    MATCH (c:Clanak) WITH zakoni, count(c) AS clanci
    OPTIONAL MATCH (s:Stavak)
    RETURN zakoni, clanci, count(s) AS stavci
''')
if stats:
    s = dict(stats[0])
    print('Graf statistike:')
    for k, v in s.items():
        print(f'  {k.capitalize()}: {v}')

# DIJAGNOSTIKA: broj clanaka po dokumentu — usporedi s RAG korpusom.
# Ako neki dokument ima sumnjivo malo clanaka, parser ga nije uhvatio.
per_doc = neo4j_run('''
    MATCH (z:Zakon)-[:SADRZI]->(c:Clanak)
    RETURN z.naziv AS zakon, count(c) AS clanaka,
           sum(CASE WHEN c.broj STARTS WITH 'pre' OR c.broj STARTS WITH 'chunk'
               THEN 1 ELSE 0 END) AS fallback
    ORDER BY zakon
''')
print('\nClanaka po dokumentu:')
for r in per_doc:
    print(f"  {r['zakon'][:55]:<57} {r['clanaka']:>4} (fallback: {r['fallback']})")

veze = neo4j_run('''
    MATCH ()-[r:UPUCUJE_NA]->()     RETURN 'UPUCUJE_NA'     AS tip, count(r) AS n
    UNION ALL
    MATCH ()-[r:RAZRADJUJE]->()     RETURN 'RAZRADJUJE'     AS tip, count(r) AS n
    UNION ALL
    MATCH ()-[r:ISTA_TEMA]->()      RETURN 'ISTA_TEMA'      AS tip, count(r) AS n
    UNION ALL
    MATCH ()-[r:SADRZI]->()         RETURN 'SADRZI'         AS tip, count(r) AS n
    UNION ALL
    MATCH ()-[r:IMA_STAVAK]->()     RETURN 'IMA_STAVAK'     AS tip, count(r) AS n
    UNION ALL
    MATCH ()-[r:SPOMINJE]->()       RETURN 'SPOMINJE'       AS tip, count(r) AS n
    UNION ALL
    MATCH ()-[r:SADRZI_OBVEZU]->()  RETURN 'SADRZI_OBVEZU'  AS tip, count(r) AS n
''')
print('\nRelacije u grafu:')
for r in veze:
    print(f"  {r['tip']:<25} {r['n']:>6} veza")

eksp = neo4j_run("MATCH ()-[r]->() WHERE r.izvor = 'ekspert' RETURN count(r) AS n")
print(f"\nEkspertnih veza (izvor='ekspert'): {eksp[0]['n'] if eksp else 0}")
# Out:
# Graf statistike:
#   Zakoni: 4
#   Clanci: 537
#   Stavci: 1414
#
# Clanaka po dokumentu:
#   Pravilnik o temeljnom vojnom osposobljavanju                23 (fallback: 1)
#   Ustav Republike Hrvatske 2018                              146 (fallback: 5)
#   Zakon o obrani 2025                                        130 (fallback: 2)
#   Zakon o sluzbi u Oruzanim snagama Republike Hrvatske 20    238 (fallback: 2)
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=17, offset=113>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 113, 'line': 4, 'column': 17}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n    MATCH ()-[r:UPUCUJE_NA]->()     RETURN 'UPUCUJE_NA'     AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:RAZRADJUJE]->()     RETURN 'RAZRADJUJE'     AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:ISTA_TEMA]->()      RETURN 'ISTA_TEMA'      AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:SADRZI]->()         RETURN 'SADRZI'         AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:IMA_STAVAK]->()     RETURN 'IMA_STAVAK'     AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:SPOMINJE]->()       RETURN 'SPOMINJE'       AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:SADRZI_OBVEZU]->()  RETURN 'SADRZI_OBVEZU'  AS tip, count(r) AS n\n"
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=6, column=17, offset=209>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 209, 'line': 6, 'column': 17}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n    MATCH ()-[r:UPUCUJE_NA]->()     RETURN 'UPUCUJE_NA'     AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:RAZRADJUJE]->()     RETURN 'RAZRADJUJE'     AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:ISTA_TEMA]->()      RETURN 'ISTA_TEMA'      AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:SADRZI]->()         RETURN 'SADRZI'         AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:IMA_STAVAK]->()     RETURN 'IMA_STAVAK'     AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:SPOMINJE]->()       RETURN 'SPOMINJE'       AS tip, count(r) AS n\n    UNION ALL\n    MATCH ()-[r:SADRZI_OBVEZU]->()  RETURN 'SADRZI_OBVEZU'  AS tip, count(r) AS n\n"
# Relacije u grafu:
#   UPUCUJE_NA                    51 veza
#   SADRZI                       537 veza
#   IMA_STAVAK                  1414 veza
#   SPOMINJE                    1563 veza
#   SADRZI_OBVEZU                488 veza
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N52', status_description='warn: property key does not exist. The property `izvor` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=1, column=26, offset=25>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 25, 'line': 1, 'column': 26}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "MATCH ()-[r]->() WHERE r.izvor = 'ekspert' RETURN count(r) AS n"
# Ekspertnih veza (izvor='ekspert'): 0

# %% [markdown]
# ## 9. Učitavanje pitanja i odgovora

# %%
try:
    with open('/content/drive/My Drive/diplomskiRad/pitanja_odgovori.json', 'r', encoding='utf-8') as f:
        qa_data = json.load(f)

    print(f"\u2713 Učitano {qa_data['metadata']['ukupno_pitanja']} pitanja i odgovora.")
    print(f"  Struktura:")
    for kategorija, info in qa_data['metadata']['struktura'].items():
        print(f"    - {kategorija}: {info['broj']} ({info['postotak']})")
except FileNotFoundError:
    print('Datoteka pitanja_odgovori.json nije pronađena na navedenoj putanji.')
    qa_data = None
except json.JSONDecodeError:
    print('Greška pri parsiranju JSON datoteke. Provjerite je li format ispravan.')
    qa_data = None
# Out:
# ✓ Učitano 43 pitanja i odgovora.
#   Struktura:
#     - kompleksna_vise_dokumenata: 12 (12.9%)
#     - kompleksna_jedan_dokument: 8 (12.9%)
#     - jednostavna: 23 (74.2%)

# %% [markdown]
# ## 10. GraphRAG retriever
#
# Retriever pretražuje Neo4j vektorski indeks i dohvaća najsličnije članke za dani upit.

# %%
def graph_retrieve_context(query: str, kategorija: str = None) -> str:
    """GraphRAG retriever — ispravke u odnosu na prvu verziju:
    1. Dohvat i po CLANCIMA i po STAVCIMA (uska pitanja pogadaju
       uski stavak, vraca se roditeljski clanak).
    2. Cap po dokumentu — garantirana pokrivenost svih akata kod
       medudokumentnih pitanja.
    3. Tipizirani traversal (UPUCUJE_NA | RAZRADJUJE | ISTA_TEMA +
       SPOMINJE preko zajednickog entiteta, samo medudokumentno)
       s tezinama po tipu veze umjesto fiksnog penaltija.
    4. Dedup po ID-u umjesto krhkog Jaccard preklapanja rijeci.
    5. top_k ovisan o kategoriji pitanja.
    """
    top_k = GRAPH_TOP_K.get(kategorija, GRAPH_TOP_K_DEFAULT)
    query_emb = embed_model.encode(['query: ' + query],
                                   normalize_embeddings=True)[0].tolist()

    # --- 1) Seed kandidati: clanak-indeks -------------------------
    res_cl = neo4j_run('''
        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)
        YIELD node AS c, score
        WHERE c.tekst IS NOT NULL
        MATCH (z:Zakon)-[:SADRZI]->(c)
        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,
               z.naziv AS zakon, score
    ''', {'k': GRAPH_VECTOR_POOL, 'emb': query_emb})

    # --- 2) Seed kandidati: stavak-indeks -> roditeljski clanak ---
    res_st = neo4j_run('''
        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)
        YIELD node AS s, score
        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)
        WHERE c.tekst IS NOT NULL
        MATCH (z:Zakon)-[:SADRZI]->(c)
        WITH c, z, max(score) AS score
        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,
               z.naziv AS zakon, score
    ''', {'k': GRAPH_VECTOR_POOL, 'emb': query_emb})

    # Spoji oba izvora; za isti clanak zadrzi bolji score
    seeds = {}
    for r in list(res_cl) + list(res_st):
        rec = {'id': r['id'], 'broj': r['broj'], 'tekst': r['tekst'] or '',
               'zakon': r['zakon'], 'score': float(r['score'])}
        if rec['id'] not in seeds or rec['score'] > seeds[rec['id']]['score']:
            seeds[rec['id']] = rec

    # --- 3) Cap po dokumentu (pokrivenost svih akata) --------------
    po_zakonu = {}
    for rec in sorted(seeds.values(), key=lambda x: x['score'], reverse=True):
        po_zakonu.setdefault(rec['zakon'], [])
        if len(po_zakonu[rec['zakon']]) < GRAPH_PER_DOC_CAP:
            po_zakonu[rec['zakon']].append(rec)
    seed_list = [rec for grupa in po_zakonu.values() for rec in grupa]
    seed_ids = [rec['id'] for rec in seed_list]
    seed_score = {rec['id']: rec['score'] for rec in seed_list}

    # --- 4) Prosirenje grafom: tipizirane veze ----------------------
    susjedi_res = neo4j_run('''
        MATCH (seed:Clanak) WHERE seed.id IN $ids

        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)
        WHERE n1.tekst IS NOT NULL
        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)

        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)
        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL
        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)

        WITH seed,
             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,
                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,
             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,
                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski
        RETURN seed.id AS sid, direktni + entitetski AS susjedi
    ''', {'ids': seed_ids})

    candidates = {rec['id']: dict(rec, rel='SEED') for rec in seed_list}
    for row in susjedi_res:
        base = seed_score.get(row['sid'], 0.0)
        for s in (row['susjedi'] or []):
            if not s or not s.get('id') or not s.get('tekst'):
                continue
            if s['id'] in candidates:      # dedup po ID-u
                continue
            w = GRAPH_REL_WEIGHTS.get(s.get('rel'), 0.7)
            candidates[s['id']] = {'id': s['id'], 'broj': s['broj'],
                                   'tekst': s['tekst'], 'zakon': s['zakon'],
                                   'score': base * w, 'rel': s.get('rel')}

    best = sorted(candidates.values(), key=lambda x: x['score'],
                  reverse=True)[:top_k]

    parts = []
    for c in best:
        tag = '' if c['rel'] == 'SEED' else f" | veza={c['rel']}"
        tekst = c['tekst'][:GRAPH_MAX_CHARS_PO_CLANKU]
        parts.append(f"[{c['zakon']}, Clanak {c['broj']} | "
                     f"score={c['score']:.2f}{tag}]\n{tekst}")
    return '\n\n---\n\n'.join(parts)

print('\u2713 GraphRAG retriever spreman (per-dokument + stavci + tipizirane veze)')
# Out:
# ✓ GraphRAG retriever spreman (per-dokument + stavci + tipizirane veze)

# %% [markdown]
# ## 10a. Ekspertne veze
#
# Rucno kurirane medudokumentne veze — sloj "ekspertnog truda" (GraphRAG-ekspert).
# Tipovi definirani unaprijed: `RAZRADJUJE` (nizi akt razraduje visi) i
# `ISTA_TEMA` (ista materija u razlicitim aktima). Svaka veza nosi
# `izvor: 'ekspert'` i `pitanje_id` radi sljedivosti i lakog uklanjanja
# (usporedba GraphRAG-auto vs GraphRAG-ekspert).
#
# **Napomena:** popuniti listu nakon pregleda pravnog eksperta (pitanja 32-43).
# ID format mora odgovarati parseru: `{zakon_id}_cl_{broj}` — provjeriti kako
# su zapisani brojevi tipa "21.m" (npr. `21m`).

# %%
EKSPERTNE_VEZE = [
    # (src_id, dst_id, TIP, pitanje_id)
    # Primjeri — ZAMIJENI stvarnim ID-evima nakon provjere numeracije:
    # ('ustav_republike_hrvatske_2018_cl_47', 'zakon_o_obrani_2025_cl_21m', 'RAZRADJUJE', 32),
    # ('zakon_o_obrani_2025_cl_21m', 'pravilnik_o_temeljnom_vojnom_osposobljavanju_cl_9', 'RAZRADJUJE', 34),
    # ('ustav_republike_hrvatske_2018_cl_100', 'zakon_o_obrani_2025_cl_15', 'ISTA_TEMA', 35),
]

def unesi_ekspertne_veze(veze):
    ok, fail = 0, []
    for src, dst, tip, pid in veze:
        if tip not in ('RAZRADJUJE', 'ISTA_TEMA'):
            fail.append((src, dst, f'nepoznat tip {tip}')); continue
        res = neo4j_run(f'''
            MATCH (a:Clanak {{id: $src}})
            MATCH (b:Clanak {{id: $dst}})
            MERGE (a)-[r:{tip} {{izvor: 'ekspert', pitanje_id: $pid}}]->(b)
            RETURN a.id AS a, b.id AS b
        ''', {'src': src, 'dst': dst, 'pid': pid})
        if res: ok += 1
        else:   fail.append((src, dst, 'cvor nije pronaden'))
    print(f'\u2713 Uneseno {ok}/{len(veze)} ekspertnih veza')
    for f in fail:
        print(f'  \u2717 {f}')

if EKSPERTNE_VEZE:
    unesi_ekspertne_veze(EKSPERTNE_VEZE)
else:
    print('(lista EKSPERTNE_VEZE je prazna — GraphRAG-auto rezim)')

# Uklanjanje svih ekspertnih veza (za GraphRAG-auto evaluaciju):
# neo4j_run("MATCH ()-[r]-() WHERE r.izvor = 'ekspert' DELETE r")
# Out:
# (lista EKSPERTNE_VEZE je prazna — GraphRAG-auto rezim)

# %% [markdown]
# ## 10b. Dijagnostika konteksta
#
# Provjera doprinosi li graf stvarno kontekstu: koliko clanaka dolazi iz
# grafa (veza=...) naspram vektorski (SEED) i koliko razlicitih zakona
# kontekst pokriva. Pokrenuti na 2-3 kompleksna pitanja **prije i poslije**
# izmjena — razlika je izravan dokaz za rad.

# %%
def dijagnoza_konteksta(query, kategorija='kompleksno_vise_dokumenata'):
    ctx = graph_retrieve_context(query, kategorija=kategorija)
    blokovi = ctx.split('\n\n---\n\n') if ctx else []
    iz_grafa = sum(1 for b in blokovi if '| veza=' in b)
    zakoni = set()
    for b in blokovi:
        header = b.split(']')[0]
        zakoni.add(header.split(',')[0].strip('['))
    print(f'Pitanje: {query[:70]}...')
    print(f'  Clanaka u kontekstu: {len(blokovi)}')
    print(f'  Iz grafa (veze):     {iz_grafa}')
    print(f'  Pokriveno zakona:    {len(zakoni)} -> {sorted(zakoni)}')
    return ctx

# Primjeri (kompleksna medudokumentna pitanja):
_ = dijagnoza_konteksta('Kako se povezuju prigovor savjesti iz Ustava, '
                        'civilna sluzba i sustav vojne obveze?')
print()
_ = dijagnoza_konteksta('Povezite ustavnu ulogu Predsjednika kao vrhovnog '
                        'zapovjednika s lancem zapovijedanja nacelnika Glavnog stozera.')
# Out:
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# Pitanje: Kako se povezuju prigovor savjesti iz Ustava, civilna sluzba i sustav ...
#   Clanaka u kontekstu: 12
#   Iz grafa (veze):     2
#   Pokriveno zakona:    4 -> ['Pravilnik o temeljnom vojnom osposobljavanju', 'Ustav Republike Hrvatske 2018', 'Zakon o obrani 2025', 'Zakon o sluzbi u Oruzanim snagama Republike Hrvatske 2025']
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# Pitanje: Povezite ustavnu ulogu Predsjednika kao vrhovnog zapovjednika s lancem...
#   Clanaka u kontekstu: 12
#   Iz grafa (veze):     0
#   Pokriveno zakona:    4 -> ['Pravilnik o temeljnom vojnom osposobljavanju', 'Ustav Republike Hrvatske 2018', 'Zakon o obrani 2025', 'Zakon o sluzbi u Oruzanim snagama Republike Hrvatske 2025']

# %% [markdown]
# ## 11. Testiranje — GraphRAG pristup
#
# GraphRAG pristup koristi Neo4j vektorski indeks za retrieval relevantnih članaka zakona, a zatim Qwen2.5-14B-Instruct generira odgovor na temelju pronađenog konteksta.

# %% [markdown]
# ### GraphRAG chat funkcija

# %%
def graph_rag_chat(user_question, kategorija=None):
    context = graph_retrieve_context(user_question, kategorija=kategorija)
    messages = [
        {'role': 'system', 'content': SYSTEM_PROMPT + '\n\nKontekst za odgovor:\n' + context},
        {'role': 'user', 'content': f'{user_question}\n\nOdgovori NA HRVATSKOM JEZIKU koristeci LATINICU.'}
    ]
    return generate_response(messages, max_new_tokens=512, temperature=0.3, do_sample=False)

# %% [markdown]
# ### Testiranje GraphRAG pristupa — sva pitanja
#
# Prolazimo kroz sva pitanja iz JSON datoteke, generiramo odgovore GraphRAG pristupom i rezultate nadopunjujemo u postojeće redove CSV datoteke kao nove stupce.

# %%
if qa_data is None:
    print('QA datoteka nije ucitana.')
else:
    df_rezultati = pd.read_csv(csv_path, encoding='utf-8-sig')

    # Mapiranje JSON kategorija -> GRAPH_TOP_K kljucevi
    KATEGORIJA_MAP = {
        'jednostavna_pitanja':                'jednostavno',
        'kompleksna_pitanja_jeden_dokument':  'kompleksno_jedan_dokument',
        'kompleksna_pitanja_vise_dokumenata': 'kompleksno_vise_dokumenata',
    }

    all_questions = []
    all_categories = []
    for key, value in qa_data.items():
        if key != 'metadata' and isinstance(value, list):
            for item in value:
                all_questions.append(item)
                all_categories.append(KATEGORIJA_MAP.get(key, key))

    graph_rag_odgovori = []
    graph_rag_vremena = []

    for i, (qa_item, kategorija) in enumerate(zip(all_questions, all_categories)):
        user_question = qa_item.get('pitanje', qa_item.get('question', ''))
        ocekivani = qa_item.get('odgovor', qa_item.get('answer', ''))

        print(f"\n{'='*80}")
        print(f'Pitanje {i + 1}/{len(all_questions)}: {user_question}')
        print(f'Kategorija: {kategorija} (top_k={GRAPH_TOP_K.get(kategorija, GRAPH_TOP_K_DEFAULT)})')
        print(f'Ocekivani odgovor: {ocekivani}')
        print(f"{'='*80}")

        answer, vrijeme = graph_rag_chat(user_question, kategorija=kategorija)

        graph_rag_odgovori.append(answer)
        graph_rag_vremena.append(round(vrijeme, 2))

    df_rezultati['graph_rag_odgovor'] = graph_rag_odgovori
    df_rezultati['graph_rag_vrijeme_sekunde'] = graph_rag_vremena
    df_rezultati.to_csv(csv_path, index=False, encoding='utf-8-sig')
    print(f"\n{'='*80}")
    print(f'GraphRAG rezultati nadopunjeni u: {csv_path}')
    print(f'Ukupno obradeno pitanja: {len(graph_rag_odgovori)}')
    print(f"Prosjecno vrijeme po pitanju: {sum(graph_rag_vremena)/len(graph_rag_vremena):.2f} sekundi")
# Out:
# ================================================================================
# Pitanje 1/43: Opišite cjelokupnu proceduru transformacije novaka u razvrstanog pričuvnika kroz sve pravne akte koji reguliraju taj proces.
# Kategorija: kompleksno_vise_dokumenata (top_k=12)
# Ocekivani odgovor: Ustav RH propisuje vojnu obvezu kao dužnost svih sposobnih državljana, uz mogućnost prigovora savjesti iz vjerskih ili moralnih razloga, uz obvezu ispunjavanja drugih dužnosti određenih zakonom. Novačka obveza nastaje u kalendarskoj godini kad državljanin RH navršava 18 godina. Državljanin RH se uvodi u vojnu evidenciju i prolazi zdravstveni i psihološki pregled. Temeljno vojno osposobljavanje traje dva mjeseca. Plan upućivanja donosi ministar obrane do 15. prosinca za iduću godinu, a pojedinačna odluka 40 dana unaprijed. Ročnici se osposobljavaju za specijalnost 11A (strijelac) i polažu prisegu. Nakon temeljnog vojnog osposobljavanja ročnik automatski postaje razvrstani pričuvnik s dodijeljenim ratnim rasporedom i vojnostručnom specijalnošću. Može biti pozvan na vježbe u maksimalnom trajanju od 90 dana godišnje. Prigovor savjesti podnosi se pisanim zahtjevom nadležnom tijelu. Odobrava se osobama čija vojna služba nije spojiva s vjerskim uvjerenjima ili moralnim načelima. Umjesto vojnog osposobljavanja, obveznik ispunjava civilnu obvezu u trajanju određenom zakonom.
# ================================================================================
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# [transformers] The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [transformers] Both `max_new_tokens` (=512) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer LlamaTokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Generirani odgovor:
# Cjelokupna procedura transformacije novaka u razvrstanog pričuvnika regulirana je slijedećim pravnim aktima:
#
# 1. **Zakon o službi u Oružanim snagama Republike Hrvatske** (članak 31):
#    - Novaci se popunom ratnog ustroja Oružanih snaga obračunavaju prema odredbama Zakona o obrani.
#    - Ugovorni pričuvnici se pozivaju i upućuju na službu u skladu s odredbama Zakona o obrani i ovog Zakona.
#
# 2. **Zakon o obrani** (članak 21.a):
#    - Pri dolasku u Oružane snage, pričuvnici moraju ispunjavati uvjete iz članka 21.a, uključujući putovanje od prebivališta do mjesta službe i natrag.
#
# 3. **Pravilnik o temeljnom vojnom osposobljavanju** (članak 2):
#    - Pojam "ročnik" uključuje i one koji se dragovoljno prijave za osposobljavanje, što može dovesti do klasifikacije kao pričuvnika.
#
# 4. **Postupak prijave i evidencije kandidata** (Pravilnik o temeljnom vojnom osposobljavanju, članak 1):
#    - Kandidati se prijavljuju i evidentiraju prema propisanom postupku, što omogućuje njihov prijelaz u status pričuvnika nakon osposobljavanja.
#
# 5. **Kriteriji za razvrstavanje u pričuvnike** (Zakon o obrani, članak 25.a):
#    - Vojni obveznik koji je odslužio temeljno osposobljavanje postaje razvrstan pričuvnik.
#
# 6. **Mogućnost dragovoljnog osposobljavanja** (Zakon o obrani, članak 25.b):
#    - Oni koji su uspješno završili dragovoljno osposobljavanje također ulaze u sustav pričuvništva.
#
# 7. **Dodatni uvjeti za razvrstavanje** (Zakon o obrani, članak 25.c-25.
# Ukupno vrijeme za odgovor: 63.14 sekundi
#
# ================================================================================
# Pitanje 2/43: Kako je regulirana hijerarhija odlučivanja o uporabi Oružanih snaga u različitim situacijama kroz Ustav i Zakon o obrani?
# Kategorija: kompleksno_vise_dokumenata (top_k=12)
# Ocekivani odgovor: Hijerarhija odlučivanja o uporabi Oružanih snaga RH razlikuje šest situacija ovisno o razini ugroze. Ratno stanje — Predsjednik Republike naređuje uporabu i zapovijeda OS-om s punom ovlašću. Odgovoran je za obranu zemlje. Stanje neposredne ugroženosti — Predsjednik može narediti uporabu, ali odluka zahtijeva supotpis predsjednika Vlade. Prelazak granice — Sabor donosi odluku većinom svih zastupnika na prijedlog Vlade uz prethodnu suglasnost Predsjednika. Ako Predsjednik uskrati suglasnost, potrebna je dvotrećinska većina Sabora. Pomoć saveznicima — Sabor donosi odluku na prijedlog Vlade uz suglasnost Predsjednika. Vježbe i obuka — Vlada donosi odluku uz suglasnost Predsjednika. Za postrojbe do razine voda odluku donosi ministar obrane samostalno. Provedba — Načelnik Glavnog stožera ima ovlast punog zapovijedanja. Odgovoran je Predsjedniku za izvršavanje zapovijedi i naredbi, a ministru obrane za provedbu odluka.
# ================================================================================
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# [transformers] Both `max_new_tokens` (=512) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generirani odgovor:
# Hierarhija odlučivanja o upotrebi Oružanih snaga u različitim situacijama regulirana je kroz **Ustav Republike Hrvatske** i **Zakon o obrani** kako slijedi:
#
# ### **Prema Ustavu (Članak 7):**
# - **Glavna tijela koja odlučuju o upotrebi Oružanih snaga:**
#   - **Hrvatski sabor**, **Predsjednik Republike**, **predsjednik Vlade** i **ministar obrane** imaju pravo odlučivati o upotrebi Oružanih snaga u skladu s Ustavom i Zakonom o obrani.
#   - Za odluke o upotrebi Oružanih snaga potrebno je **višeinsko glasovanje svih zastupnika Hrvatskog sabora** (osim u izuzetim slučajevima kada je potrebna dvotrećinska većina).
#
# - **Provjera supsidijarnosti:**
#   - Ako Predsjednik Republike odbije suglasnost za uporabu Oružanih snaga, Hrvatski sabor donosi odluku **dvotrećinskom većinom**.
#
# ### **Prema Zakonu o obrani (Članak 46 & 57–58):**
# - **Definiranje tijela koja donose odluke:**
#   - **Vlada** ili **ministar obrane** donose odluke o upotrebi Oružanih snaga (npr. u miru, ratu, izvanrednim situacijama).
#   - **Naredbe** se izvršavaju putem **zapovjedi načelnika Glavnog stožera**.
#
# - **Posebni slučajevi:**
#   - U slučaju napada na zračnu suverenost RH, upotreba Oružanih snaga regulirana je posebnim zakonom.
#   - U ratu, odluke donose isti akteri (Sabor, Predsjednik, Vlada, ministar obrane), ali s jasnijom procedurom.
#
# ### **Izvješće:**
# Hierarhija je jasno definirana: **najviša odlučna vlast pripada Hrvatskom saboru**, a **izvedbene ovlasti** ima Vlada i ministar obrane, uz kontrolu predsjednika. U izvanrednim situacijama (npr. rat) procedura je detaljnije regulirana.
# Ukupno vrijeme za odgovor: 63.58 sekundi
#
# ================================================================================
# Pitanje 3/43: Objasnite sustav imenovanja i odgovornosti načelnika Glavnog stožera kroz sve relevantne propise.
# Kategorija: kompleksno_vise_dokumenata (top_k=12)
# Ocekivani odgovor: Položaj načelnika Glavnog stožera OS RH reguliran je kroz pet razina. Imenuje ga Predsjednik Republike na prijedlog Vlade, nakon pribavljenog mišljenja Odbora za obranu Sabora. Mandat traje četiri godine bez mogućnosti ponovnog imenovanja. Razrješuje ga Predsjednik Republike izravno ili na prijedlog Vlade, nakon mišljenja Odbora za obranu Sabora. Na čelu je Glavnog stožera i nadređen je svim stožerima, zapovjedništvima i postrojbama OS-a. Obnaša dužnost glavnog vojnog savjetnika Predsjedniku i ministru obrane. Ima ovlast punog zapovijedanja u OS-u. Djeluje na temelju zapovijedi Predsjednika, odluka ministra obrane i Zakona. Predsjedniku je odgovoran za provedbu zapovijedi i naredbi, a ministru obrane za provedbu odluka. Obvezan je istodobno izvještavati oba o uporabi Oružanih snaga.
# ================================================================================
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# [transformers] Both `max_new_tokens` (=512) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generirani odgovor:
# Sustav imenovanja i odgovornosti **Načelnika Glavnog stožera** Oružanih snaga Republike Hrvatske (HRZ) reguliran je Zakonom o obrani i drugim relevantnim propisima. Evo ključnih elemenata:
#
# ### **Imenovanje Načelnika Glavnog stožera**
# Prema **Članku 15. Zakona o obrani (2025.)**:
# - **Načelnik Glavnog stožera** imenuje se na razdoblje od **četiri godine** i ne može biti ponovno imenovan.
# - **Dužnost** traje do isteka mandata, ali ako je osoba već postavljena na tu poziciju prije stupanja na snagu ovog zakona, zadržava ju do isteka tog mandata (vidi **Članak 123.**).
# - **Predlog** za imenovanje daje načelnik Glavnog stožera, a **suglasnost** daje ministar obrane.
# - **Ustroj Glavnog stožera** određuje Predsjednik Republike na taj prijedlog.
#
# ### **Odgovornosti Načelnika Glavnog stožera**
# Prema **Članku 70. Zakona o obrani (2025.)**:
# 1. **Operativno zapovjedništvo** – Načelnik Glavnog stožera ima punu ovlast zapovjedanja u HRZ na temelju direktiva Predsjednika Republike, odluka ministra obrane i zakona.
# 2. **Izvršavanje naredaba** – Dužan je izvesti naredbe Predsjednika i ministra obrane, a o njihovoj provedbi mora ih **istodobno obavijestiti**.
# 3. **Privremena mobilizacija** – U slučaju opasnosti (katastrofe, velike nesreće), može naredio privremenu mobilizaciju dijelova snaga i mora o tome odmah izvijestiti predsjednika i ministra.
# 4. **Reprezentativna uloga** – Radi kao glavni vojni savjetnik Predsjedniku i ministru obrane.
#
# ### **Ostale važne odredbe**
# - Prema **Članku 15.**, Načelnik Glavnog stožera je **nadređen svim postrojbama** u HRZ.
# - Prema **Članku 9.
# Ukupno vrijeme za odgovor: 63.13 sekundi
#
# ================================================================================
# Pitanje 4/43: Objasnite sve oblike obveza državljana u obrani prema Zakonu o obrani i Ustavu.
# Kategorija: kompleksno_vise_dokumenata (top_k=12)
# Ocekivani odgovor: Vojna obveza i obrana RH dužnost je svih sposobnih državljana, uz mogućnost prigovora savjesti. Vojna obveza nastaje u godini navršenja 18 godina. Prestaje s 55 godina za muškarce odnosno 50 godina za žene. Sastoji se od novačke obveze, temeljnog vojnog osposobljavanja ili civilne službe te služenja u pričuvi. Služenje u ugovornoj pričuvi - nakon dragovoljnog vojnog osposobljavanja ili temeljnog vojnog osposobljavanje. Osposobljavanje pričuve traje do 90 dana godišnje. Radna obveza nameće se pravnim osobama i državljanima RH. Aktivira se u ratnom stanju i stanju neposredne ugroženosti. Radna pomoć se može uvesti u ratnom stanju i stanju neposredne ugroženosti radi izvršenja zadaća nositelja obrambenih funkcija. Materijalna obveza podrazumijeva ustupanje objekata i materijalnih sredstava za potrebe obrambenih zadaća i osposobljavanja.
# ================================================================================
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# [transformers] Both `max_new_tokens` (=512) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generirani odgovor:
# Prema **Zakonu o obrani** i **Ustavu Republike Hrvatske**, građani imaju različite oblike obveza u obrani:
#
# ### 1. **Vojna obveza**
# - Prema **Članku 19.** Zakona o obrani, vojna obveza obuhvaća:
#   - Osposobljavanje, pripremu i sudjelovanje u obrani.
#   - Nastaje u kalendarskoj godini kada građanin navrši **18 godina**.
# - Ustav (**Članak 47.**) također spominje da je obrana domovine dužnost građana.
#
# ### 2. **Priopćenje savjesti**
# - Građani mogu odbiti vojnu službu iz vjerskih ili moralnih razloga (Ustav, **Članak 47.**).
# - Moraju ispunjavati druge zakonske obveze umjesto vojne službe.
#
# ### 3. **Radna i materijalna obveza**
# - Prema **Članku 21.f.** Zakona o obrani, građani su dužni pružiti materijalnu potporu obrani.
# - Postoji i **radna obveza** (npr. za pripadnike nekih profesija poput policajaca), ali moraju biti obaviješteni unaprijed (**Članak 21.j.**).
#
# ### 4. **Druge posebne obveze**
# - Za određene skupine (npr. studente, umirovljenike) postoje odgode ili izuzeća (**Članak 21.k–q.**).
# - Građani moraju poštovati odluke nadležnih tijela (npr. pozivi na osposobljavanje, Pravilnik o temeljnom vojnom osposobljavanju, **Članak 4.**).
#
# Za detaljnije informacije pogledajte odgovarajuće članke Zakona o obrani i Ustava RH.
# Ukupno vrijeme za odgovor: 55.94 sekundi
#
# ================================================================================
# Pitanje 5/43: Kako se povezuju prigovor savjesti iz Ustava, civilna sluzba i sustav vojne obveze kroz Ustav i Zakon o obrani, i koje su posljedice odabira civilne sluzbe za status osobe?
# Kategorija: kompleksno_vise_dokumenata (top_k=12)
# Ocekivani odgovor: Ustav RH jamci pravo na prigovor savjesti svima koji zbog vjerskih ili moralnih nazora nisu pripravni sudjelovati u obavljanju vojnih duznosti, uz obvezu ispunjavanja drugih duznosti odredenih zakonom. Zakon o obrani tu ustavnu odredbu razraduje kroz institut vojne obveze koja nastaje u godini punoljetnosti, te propisuje da osoba s odobrenim prigovorom savjesti umjesto vojne obveze ispunjava civilnu obvezu. Posljedica je da takva osoba ne ulazi u rocnicki/pricuvni put kroz temeljno vojno osposobljavanje, nego se njezina obrambena duznost ostvaruje u nevojnom obliku, cime se ustavno nacelo (sloboda savjesti) i zakonska obveza (doprinos obrani) uskladuju.
# ================================================================================
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# [transformers] Both `max_new_tokens` (=512) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generirani odgovor:
# Prema **Ustavu Republike Hrvatske** (Brojevi 47), prigovor savjesti dopušten je građanima koji iz vjerskih ili moralnih razloga ne prihvaćaju sudjelovanje u vojnim aktivnostima. Takve osobe moraju ispunjavati alternativne dužnosti prema zakonu.
#
# ### **Sustav vojne obveze i civilna služba**
# - **Zakon o obrani** (Članak 24.) definira uvjete za priznavanje prigovora savjesti i oslobađanje od vojne službe. Osoba koja odabere civilnu službu ne mora odslužiti vojnu obvezu, ali je dužna prijaviti razlog (npr. vjerski ili moralni prigovor).
# - **Civilna služba** (prema istom članku) može se odobriti ako osoba dokaže opravdane razloge (npr. zdravstveno stanje, obiteljski odnosi, zaposlenje). Rok za prijavu je strogo definisan (do 30. lipnja u godini kada navrši 29 godina).
#
# ### **Posljedice odabira civilne službe**
# 1. **Status osobe**:
#    - Ostaje u sustavu vojne obveze, ali je oslobođena vojne službe.
#    - Ako odbaci civilnu službu bez opravdanog razloga, može biti kažnjena (npr. novčanom globom).
# 2. **Dugoročne posljedice**:
#    - Za određene profesije (policija, vojska) odabir civilne službe može otežati karijeru.
#    - Ako osoba kasnije želi pristupiti vojsci, može biti testirana na sposobnost.
#
# ### **Nadležna tijela**
# - **Ministarstvo obrane** (prema Zakonu o obrani, Članak 24.g) provjerava podneske i donosi odluku.
# - **Područni odjeli za poslove obrane** (Članak 21.) koordiniraju prijave i zdravstvene provjere.
#
# Izbor civilne službe je zakonit, ali podložan strogim kriterijima. Osoba zadržava status obveznika, ali izbjegava vojnu prisilu uz uvjet poštivanja uvjeta iz zakona.
# Ukupno vrijeme za odgovor: 62.87 sekundi
#
# ================================================================================
# Pitanje 6/43: Objasnite cijeli put zdravstvene i psiholoske procjene novaka - od poziva do upisa u evidenciju - povezujuci Zakon o obrani s Pravilnikom o temeljnom vojnom osposobljavanju.
# Kategorija: kompleksno_vise_dokumenata (top_k=12)
# Ocekivani odgovor: Zakon o obrani uspostavlja vojnu evidenciju i ovlast Ministarstva obrane da poziva obveznike, a detaljnu provedbu propisuje Pravilnik o temeljnom vojnom osposobljavanju. Po Pravilniku nadlezni podrucni odjel za poslove obrane poziva kandidata na zdravstveni pregled i psihologijsko ispitivanje, upoznaje ga s pravima i obvezama, izdaje uputnicu te osigurava prijevoz ili naknadu troskova. Kandidat se mora odazvati; u slucaju sprijecenosti duzan je u roku od tri dana obavijestiti odjel, koji odreduje novi termin. Nakon osposobljavanja nadlezna ustrojstvena jedinica u evidenciju, vojnu iskaznicu i informacijski sustav upisuje datume pocetka i zavrsetka osposobljavanja, vojnostrucnu specijalnost i datum prisege.
# ================================================================================
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# ...
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# [transformers] Both `max_new_tokens` (=512) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generirani odgovor:
# Djelatnoj vojnoj osobi u slučaju rođenja djeteta pripada **sedam radnih dana** plaćenog dopusta, kako je definirano u [Zakon o službi u Oružanim snagama Republike Hrvatske 2025, Članak 159](https://www.narodne-novine.hr/#_133086). Ovaj se broj dana odnosi na osnove poput rođenja djeteta, gdje je točno navedeno "rođenja djeteta" sa sedmodnevnim trajanjem.
# Ukupno vrijeme za odgovor: 14.68 sekundi
#
# ================================================================================
# Pitanje 42/43: Koliko dana plaćenog dopusta pripada djelatnoj vojnoj osobi u slučaju zaključenja braka?
# Kategorija: jednostavno (top_k=5)
# Ocekivani odgovor: Djelatna vojna osoba ima pravo na plaćeni dopust od sedam radnih dana u slučaju zaključenja braka.
# ================================================================================
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# [transformers] Both `max_new_tokens` (=512) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generirani odgovor:
# Djelatnoj vojnoj osobi u slučaju zaključenja braka pripada **sedam radnih dana** plaćenog dopusta, kako je definirano u **Članku 159.** Zakona o službi u Oružanim snagama Republike Hrvatske.
#
# Ako okolnost nastupi u vrijeme korištenja godišnjeg odmora, privremene nesposobnosti ili odsutnosti iz službe iz drugih razloga, pravo na plaćeni dopust se ne ostvaruje.
# Ukupno vrijeme za odgovor: 13.97 sekundi
#
# ================================================================================
# Pitanje 43/43: Što je vojna iskaznica i tko ju izdaje?
# Kategorija: jednostavno (top_k=5)
# Ocekivani odgovor: Vojna iskaznica je javna isprava kojom vojni obveznik dokazuje identitet dok izvršava vojnu obvezu. Izdaje ju nadležni područni odjel za poslove obrane koji vojnog obveznika vodi u evidenciji.
# ================================================================================
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('clanak_embedding', $k, $emb)\n        YIELD node AS c, score\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N01', status_description='warn: feature deprecated with replacement. db.index.vector.queryNodes is deprecated. It is replaced by SEARCH.', position=<SummaryInputPosition line=2, column=9, offset=9>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 9, 'line': 2, 'column': 9}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        CALL db.index.vector.queryNodes('stavak_embedding', $k, $emb)\n        YIELD node AS s, score\n        MATCH (c:Clanak)-[:IMA_STAVAK]->(s)\n        WHERE c.tekst IS NOT NULL\n        MATCH (z:Zakon)-[:SADRZI]->(c)\n        WITH c, z, max(score) AS score\n        RETURN c.id AS id, c.broj AS broj, c.tekst AS tekst,\n               z.naziv AS zakon, score\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `RAZRADJUJE` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=45, offset=96>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 96, 'line': 4, 'column': 45}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# WARNING:neo4j.notifications:Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `ISTA_TEMA` does not exist in database `ad1afaa8`. Verify that the spelling is correct.', position=<SummaryInputPosition line=4, column=56, offset=107>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 107, 'line': 4, 'column': 56}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "\n        MATCH (seed:Clanak) WHERE seed.id IN $ids\n\n        OPTIONAL MATCH (seed)-[r:UPUCUJE_NA|RAZRADJUJE|ISTA_TEMA]-(n1:Clanak)\n        WHERE n1.tekst IS NOT NULL\n        OPTIONAL MATCH (zn1:Zakon)-[:SADRZI]->(n1)\n\n        OPTIONAL MATCH (seed)-[:SPOMINJE]->(e:Entitet)<-[:SPOMINJE]-(n2:Clanak)\n        WHERE n2.zakon_id <> seed.zakon_id AND n2.tekst IS NOT NULL\n        OPTIONAL MATCH (zn2:Zakon)-[:SADRZI]->(n2)\n\n        WITH seed,\n             collect(DISTINCT {id: n1.id, broj: n1.broj, tekst: n1.tekst,\n                               zakon: zn1.naziv, rel: type(r)})[0..4]  AS direktni,\n             collect(DISTINCT {id: n2.id, broj: n2.broj, tekst: n2.tekst,\n                               zakon: zn2.naziv, rel: 'SPOMINJE'})[0..3] AS entitetski\n        RETURN seed.id AS sid, direktni + entitetski AS susjedi\n    "
# [transformers] Both `max_new_tokens` (=512) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generirani odgovor:
# Vojna iskaznica je identifikacijski dokument koji dokazuje pripadnost Oružanim snagama Republike Hrvatske. Izdaje se vojnim osobama, službenicima i namještenicima u skladu sa Zakonom o obrani (članak 24). Ministar obrane propisuje oblik i sadržaj ove iskaznice pravilnikom. Ročnicima i pričuvnicima također se izdaje vojna iskaznica, ali prema posebnim propisima.
# Ukupno vrijeme za odgovor: 12.28 sekundi
#
# ================================================================================
# GraphRAG rezultati nadopunjeni u: /content/drive/My Drive/diplomskiRad/rezultati.csv
# Ukupno obradeno pitanja: 43
# Prosjecno vrijeme po pitanju: 33.46 sekundi
