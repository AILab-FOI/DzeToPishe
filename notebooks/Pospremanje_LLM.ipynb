# %%
# ============================================================
# JEDNOKRATNO SKIDANJE LLM-a NA GOOGLE DRIVE
# Pokreni samo jednom po modelu.
# ============================================================

import os
from google.colab import drive, userdata

# 1. Povlačenje tokena iz Colab Secrets i postavljanje u okolinu
try:
    os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
    print("HF Token uspješno učitan iz Secrets!")
except Exception as e:
    print("Greška: Provjeri jesi li dodao 'HF_TOKEN' u Colab Secrets i odobrio pristup bilježnici.")

os.environ["HF_HOME"] = "/content/drive/MyDrive/hf_cache"
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# 2. Montiranje Google Drive-a
drive.mount('/content/drive')

# 3. Instalacija paketa
# !pip install -q hf_transfer huggingface_hub

# 4. Preuzimanje modela
from huggingface_hub import snapshot_download

# model_name = "Qwen/Qwen2.5-14B-Instruct"
model_name = "utter-project/EuroLLM-22B-Instruct-2512"

putanja = snapshot_download(model_name)
print(f"Model pohranjen na Drive: {putanja}")
# Out:
# HF Token uspješno učitan iz Secrets!
# Mounted at /content/drive
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 29.5 MB/s eta 0:00:00
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:298: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# ...
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# Model pohranjen na Drive: /content/drive/MyDrive/hf_cache/hub/models--utter-project--EuroLLM-22B-Instruct-2512/snapshots/38196362cf70aebbc19d1acb9ebc7c18ef81d1b2
